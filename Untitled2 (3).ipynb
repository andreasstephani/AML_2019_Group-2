# %% [markdown]
# #Coursework Part 1

# %% [markdown]
# ##Gradient Descent

# %% [markdown]
# ###Why is gradient descent important in machine learning?
#
# Gradient descent is an optimization technique which can be used to minimise a function. This is a very important and useful tool in machine learning. Machine Learning models have a cost function, which is a way to determine how well the model has performed given the different values of each of its parameters. Therefore, gradient descent can be used to find the parameter values that minimise the cost function of the model (i.e. find the parameters that give the lowest cost). An example can be a linear regression model where the parameters are the beta coefficients and the cost function is the mean squared error (MSE). Thus, gradient descent could be used to find the beta coefficients that minimise the MSE of the linear regression model.

# %% [markdown]
# ###How does plain vanilla gradient descent work?
#
# Plain vanilla gradient descent can be used to minimise a function (i.e. find the minimum point of the function). The procedure of doing this starts by choosing a starting point that lies within the domain of the chosen function. The very first step is usually a downhill movement from the starting point towards the direction specified by the gradient at that point. Then, the gradient at the new point is recalculated, and another step is taken in the direction that it specifies. This process is repeated until the global minimum of the function or a point where no more downhill movement can be made (i.e. a local minimum) is reached.

# %% [markdown]
# ##Gradient descent class

# %%
import numpy as np

class gd_andreas_2d:
    
    def __init__(self, fn_loss, fn_grad1, fn_grad2):
        self.fn_loss = fn_loss
        self.fn_grad1 = fn_grad1
        self.fn_grad2 = fn_grad2
        
    def find_min(self, x_1_init,x_2_init, n_iter, eta, tol):
        #self.x_1_init = x_1_init
        #self.x_2_init = x_2_init
        #self.n_iter = n_iter
        #self.eta = eta
        #self.tol = tol
        
        x_1 = x_1_init
        x_2 = x_2_init
        
        loss_path = []
        x_1_path = []
        x_2_path = []
        
        x_1_path.append(x_1)
        x_2_path.append(x_2)
        loss_this = self.fn_loss(x_1,x_2)
        loss_path.append(loss_this)
        g1 = self.fn_grad1(x_1,x_2)
        g2 = self.fn_grad2(x_1,x_2)

        for i in range(n_iter):
            if (np.abs(g1) < tol and np.abs(g2) < tol) or np.isnan(g1) or np.isnan(g2):
                break
            g1 = self.fn_grad1(x_1,x_2)
            g2 = self.fn_grad2(x_1,x_2)
            x_1 += -eta * g1
            x_2 += -eta * g2
            x_1_path.append(x_1)
            x_2_path.append(x_2)
            loss_this = self.fn_loss(x_1,x_2)
            loss_path.append(loss_this)
            
        if np.isnan(g1) or np.isnan(g2):
            print('Exploded')
        elif np.abs(g1) > tol or np.abs(g2) > tol:
            print('Did not converge')
        else:
            print('Converged in {} steps.  Loss fn = {} achieved by x_1 = {} and x_2 = {}'.format(i+1, loss_this, x_1,x_2))
        
        self.loss_path = loss_path
        self.x1_path = x_1_path
        self.x2_path = x_2_path
        self.loss_fn_min = loss_this
        self.x1_at_min = x_1
        self.x2_at_min = x_2
        self.g_x1 = g1
        self.g_x2 = g2
        self.num_step = i+1
      
    
    def momentum(self, x_1_init, x_2_init, n_iter, eta, tol, alpha):
        
        x_1 = x_1_init
        x_2 = x_2_init
        
        loss_path = []
        x_1_path = []
        x_2_path = []
        
        x_1_path.append(x_1)
        x_2_path.append(x_2)
        loss_this = self.fn_loss(x_1,x_2)
        loss_path.append(loss_this)
        g1 = self.fn_grad1(x_1,x_2)
        g2 = self.fn_grad2(x_1,x_2)
        nu_1 = 0
        nu_2 = 0

        for i in range(n_iter):
            g1 = self.fn_grad1(x_1,x_2)
            g2 = self.fn_grad2(x_1,x_2)
            if (np.abs(g1) < tol and np.abs(g2) < tol) or np.isnan(g1) or np.isnan(g2):
                break

            nu_1 = alpha * nu_1 + eta * g1
            nu_2 = alpha * nu_2 + eta * g2
            x_1 += -nu_1
            x_2 += -nu_2
            x_1_path.append(x_1)
            x_2_path.append(x_2)
            loss_this = self.fn_loss(x_1,x_2)
            loss_path.append(loss_this)

        if np.isnan(g1) or np.isnan(g2):
            print('Exploded')
        elif np.abs(g1) > tol or np.abs(g2) > tol:
            print('Did not converge')
        else:
            print('Converged in {} steps.  Loss fn = {} achieved by x_1 = {} and x_2 = {}'.format(i+1, loss_this, x_1,x_2))
        
        self.loss_path = loss_path
        self.x1_path = x_1_path
        self.x2_path = x_2_path
        self.loss_fn_min_momentum = loss_this
        self.x1_at_min_momentum = x_1
        self.x2_at_min_momentum = x_2
        self.g_x1 = g1
        self.g_x2 = g2
        self.num_step = i+1
       

    def nag(self, x_1_init, x_2_init, n_iter, eta, tol, alpha):
        x_1 = x_1_init
        x_2 = x_2_init
        
        loss_path = []
        x_1_path = []
        x_2_path = []
        
        x_1_path.append(x_1)
        x_2_path.append(x_2)
        loss_this = self.fn_loss(x_1,x_2)
        loss_path.append(loss_this)
        g1 = self.fn_grad1(x_1,x_2)
        g2 = self.fn_grad2(x_1,x_2)
        nu_1 = 0
        nu_2 = 0

        for i in range(n_iter):
            # i starts from 0 so add 1
            # The formula for mu was mentioned by David Barber UCL as being Nesterovs suggestion
            mu = 1 - 3 / (i + 1 + 5) 
            g1 = self.fn_grad1(x_1 - mu*nu_1,x_2 - mu*nu_1)
            g2 = self.fn_grad2(x_2 - mu*nu_2,x_2 - mu*nu_2)
     
            if (np.abs(g1) < tol and np.abs(g2) < tol) or np.isnan(g1) or np.isnan(g2):
                break

            nu_1 = alpha * nu_1 + eta * g1
            nu_2 = alpha * nu_2 + eta * g2
            x_1 += -nu_1
            x_2 += -nu_2
            x_1_path.append(x_1)
            x_2_path.append(x_2)
            loss_this = self.fn_loss(x_1,x_2)
            loss_path.append(loss_this)

        if np.isnan(g1) or np.isnan(g2):
            print('Exploded')
        elif np.abs(g1) > tol or np.abs(g2) > tol:
            print('Did not converge')
        else:
            print('Converged in {} steps.  Loss fn = {} achieved by x_1 = {} and x_2 ={}'.format(i+1, loss_this, x_1,x_2))
        self.loss_path = loss_path
        self.x1_path = x_1_path
        self.x2_path = x_2_path
        self.loss_fn_min_nag = loss_this
        self.x1_at_min_nag = x_1
        self.x2_at_min_nag = x_2
        self.g_x1 = g1
        self.g_x2 = g2
        self.num_step = i+1

# %%
def fn_loss(x_1,x_2):
    return (4*x_1**2) - 2.1*x_1**4 + (x_1**6)/3 + x_1*x_2 - 4*x_2**2 + 4*x_2**4
    
def fn_grad1(x_1,x_2):
    return 8*x_1 - 8.4*x_1**3 + 2*x_1**5 + x_2
    
def fn_grad2(x_1,x_2): 
    return x_1 - 8*x_2 + 16*x_2**3

# %%
solver = gd_andreas_2d(fn_loss = fn_loss, fn_grad1 = fn_grad1, fn_grad2 = fn_grad2)

# %%
solver.find_min(x_1_init=1, x_2_init=1, n_iter = 10000, eta= 0.001, tol=1e-5)
# Out:
# Converged in 1839 steps.  Loss fn = -1.031628453483402 achieved by x_1 = -0.08984072319727252 and x_2 = 0.7126562546861168

# %%
solver.momentum(x_1_init = 1, x_2_init = 1, n_iter = 1000, eta = 0.001, tol = 1e-5, alpha=0.90)
# Out:
# Converged in 258 steps.  Loss fn -1.0316284534849685 achieved by x_1 = -0.08984308295044065 and x_2 = 0.7126567109023105

# %%
solver.nag(x_1_init = 1, x_2_init = 1, n_iter = 10000, eta = 0.001, tol = 1e-5, alpha=0.995)
# Out:
# Converged in 1153 steps.  Loss fn -0.04249454279124776 achieved by x_1 = 1.6964054050173616 and x_2 =-0.6614388591248741

# %%
import matplotlib
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
# %matplotlib inline

font = {'size': 18}
matplotlib.rc('font', **font)

fig = plt.figure(figsize=(15,15))
ax = plt.axes(projection="3d")

z_points = solver.loss_path
x_points = solver.x1_path
y_points = solver.x2_path
ax.scatter3D(x_points, y_points, z_points,c=z_points);
ax.set_xlabel('x_1')
ax.set_ylabel('x_2')
ax.set_zlabel('loss')
plt.show()

# %%
eta_path=[]
stepsize_path=[]

for j in range (1,2000):
  r=(j/2000)
  tolerance=1e-10
  solver.find_min(x_1_init=0.5, x_2_init=0.5, n_iter = 10000, eta=r, tol=tolerance)
  if solver.g_x1>tolerance or solver.g_x2>tolerance:
    break
  eta_path.append(r)
  stepsize_path.append(solver.num_step)
# Out:
# Converged in 6397 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308735218 and x_2 = 0.7126564030192485
# Converged in 3194 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308746097 and x_2 = 0.7126564030192611
# Converged in 2126 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308752068 and x_2 = 0.7126564030192681
# Converged in 1592 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308758114 and x_2 = 0.7126564030192751
# Converged in 1272 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308774016 and x_2 = 0.7126564030192933
# Converged in 1058 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.089842013087704 and x_2 = 0.7126564030192889
# Converged in 906 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308796047 and x_2 = 0.7126564030193185
# Converged in 791 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308782973 and x_2 = 0.7126564030193034
# Converged in 702 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308789365 and x_2 = 0.7126564030193108
# Converged in 631 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130880547 and x_2 = 0.7126564030193294
# Converged in 573 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308826244 and x_2 = 0.7126564030193533
# Converged in 524 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308808948 and x_2 = 0.7126564030193334
# Converged in 483 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308820396 and x_2 = 0.7126564030193466
# Converged in 448 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308841294 and x_2 = 0.7126564030193706
# Converged in 417 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308814786 and x_2 = 0.7126564030193402
# Converged in 391 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201308873338 and x_2 = 0.7126564030194075
# Converged in 367 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308847656 and x_2 = 0.712656403019378
# Converged in 346 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308849943 and x_2 = 0.7126564030193805
# Converged in 327 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308833344 and x_2 = 0.7126564030193613
# Converged in 311 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308918821 and x_2 = 0.7126564030194598
# Converged in 295 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308857304 and x_2 = 0.7126564030193889
# Converged in 281 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308850485 and x_2 = 0.7126564030193812
# Converged in 269 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308926645 and x_2 = 0.7126564030194688
# Converged in 257 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308893297 and x_2 = 0.7126564030194303
# Converged in 246 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308863611 and x_2 = 0.7126564030193963
# Converged in 237 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308970144 and x_2 = 0.7126564030195187
# Converged in 227 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308874346 and x_2 = 0.7126564030194087
# Converged in 219 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308941328 and x_2 = 0.7126564030194855
# Converged in 211 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308935626 and x_2 = 0.7126564030194791
# Converged in 204 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308991135 and x_2 = 0.7126564030195429
# Converged in 197 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308985927 and x_2 = 0.7126564030195369
# Converged in 190 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308918674 and x_2 = 0.7126564030194595
# Converged in 184 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308935824 and x_2 = 0.7126564030194793
# Converged in 179 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309046276 and x_2 = 0.7126564030196063
# Converged in 173 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308965405 and x_2 = 0.7126564030195133
# Converged in 168 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308986611 and x_2 = 0.7126564030195377
# Converged in 163 steps.  Loss fn = -1.0316284534898779 achieved by x_1 = -0.0898420130896424 and x_2 = 0.7126564030195119
# Converged in 159 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309061056 and x_2 = 0.7126564030196233
# Converged in 154 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308958947 and x_2 = 0.712656403019506
# Converged in 150 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308985164 and x_2 = 0.712656403019536
# Converged in 146 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308976218 and x_2 = 0.7126564030195258
# Converged in 143 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309108562 and x_2 = 0.7126564030196779
# Converged in 139 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309040554 and x_2 = 0.7126564030195996
# Converged in 136 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309116917 and x_2 = 0.7126564030196875
# Converged in 132 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201308985244 and x_2 = 0.7126564030195361
# Converged in 129 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309011725 and x_2 = 0.7126564030195666
# Converged in 126 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309012146 and x_2 = 0.7126564030195671
# Converged in 123 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308986361 and x_2 = 0.7126564030195375
# Converged in 121 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130913914 and x_2 = 0.7126564030197131
# Converged in 118 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309072953 and x_2 = 0.712656403019637
# Converged in 116 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309181901 and x_2 = 0.7126564030197623
# Converged in 113 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130907479 and x_2 = 0.7126564030196392
# Converged in 111 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309150755 and x_2 = 0.7126564030197264
# Converged in 109 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309206995 and x_2 = 0.7126564030197912
# Converged in 106 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309036176 and x_2 = 0.7126564030195947
# Converged in 104 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309062936 and x_2 = 0.7126564030196254
# Converged in 102 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.089842013090727 and x_2 = 0.7126564030196367
# Converged in 100 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309065855 and x_2 = 0.7126564030196288
# Converged in 98 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309041924 and x_2 = 0.7126564030196013
# Converged in 97 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309237419 and x_2 = 0.7126564030198261
# Converged in 95 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309192871 and x_2 = 0.7126564030197748
# Converged in 93 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309129995 and x_2 = 0.7126564030197026
# Converged in 92 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309283765 and x_2 = 0.7126564030198794
# Converged in 90 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309202607 and x_2 = 0.7126564030197862
# Converged in 88 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309095881 and x_2 = 0.7126564030196634
# Converged in 87 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309228736 and x_2 = 0.7126564030198161
# Converged in 85 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309096468 and x_2 = 0.712656403019664
# Converged in 84 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309211967 and x_2 = 0.7126564030197968
# Converged in 83 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309307313 and x_2 = 0.7126564030199065
# Converged in 81 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309148884 and x_2 = 0.7126564030197243
# Converged in 80 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309234391 and x_2 = 0.7126564030198226
# Converged in 79 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130930556 and x_2 = 0.7126564030199045
# Converged in 77 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309104861 and x_2 = 0.7126564030196737
# Converged in 76 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309168574 and x_2 = 0.712656403019747
# Converged in 75 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309220977 and x_2 = 0.7126564030198073
# Converged in 74 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309263581 and x_2 = 0.7126564030198561
# Converged in 73 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309297578 and x_2 = 0.7126564030198953
# Converged in 72 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130932388 and x_2 = 0.7126564030199256
# Converged in 71 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309343177 and x_2 = 0.7126564030199477
# Converged in 70 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309355949 and x_2 = 0.7126564030199625
# Converged in 69 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309362501 and x_2 = 0.7126564030199699
# Converged in 68 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309362962 and x_2 = 0.7126564030199705
# Converged in 67 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309357298 and x_2 = 0.7126564030199639
# Converged in 66 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309345304 and x_2 = 0.7126564030199503
# Converged in 65 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309326592 and x_2 = 0.7126564030199286
# Converged in 64 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309300573 and x_2 = 0.7126564030198987
# Converged in 63 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309266424 and x_2 = 0.7126564030198594
# Converged in 62 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309223039 and x_2 = 0.7126564030198096
# Converged in 62 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309463948 and x_2 = 0.7126564030200866
# Converged in 61 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130942369 and x_2 = 0.7126564030200403
# Converged in 60 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130937424 and x_2 = 0.7126564030199835
# Converged in 59 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309313787 and x_2 = 0.712656403019914
# Converged in 58 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309240017 and x_2 = 0.7126564030198291
# Converged in 58 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309468359 and x_2 = 0.7126564030200917
# Converged in 57 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309401761 and x_2 = 0.7126564030200151
# Converged in 56 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309320164 and x_2 = 0.7126564030199213
# Converged in 55 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.089842013092198 and x_2 = 0.7126564030198058
# Converged in 55 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309448107 and x_2 = 0.7126564030200684
# Converged in 54 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309356137 and x_2 = 0.7126564030199627
# Converged in 53 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309241517 and x_2 = 0.7126564030198309
# Converged in 53 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309460103 and x_2 = 0.7126564030200823
# Converged in 52 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309353193 and x_2 = 0.7126564030199593
# Converged in 52 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309539785 and x_2 = 0.7126564030201739
# Converged in 51 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130943898 and x_2 = 0.712656403020058
# Converged in 50 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309309787 and x_2 = 0.7126564030199094
# Converged in 50 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309504788 and x_2 = 0.7126564030201336
# Converged in 49 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309380024 and x_2 = 0.7126564030199901
# Converged in 49 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309554893 and x_2 = 0.7126564030201912
# Converged in 48 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.0898420130943274 and x_2 = 0.7126564030200507
# Converged in 48 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309592366 and x_2 = 0.7126564030202343
# Converged in 47 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130947102 and x_2 = 0.7126564030200947
# Converged in 46 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309307997 and x_2 = 0.7126564030199073
# Converged in 46 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309496986 and x_2 = 0.7126564030201246
# Converged in 45 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309330225 and x_2 = 0.7126564030199328
# Converged in 45 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309511994 and x_2 = 0.7126564030201419
# Converged in 44 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309338581 and x_2 = 0.7126564030199424
# Converged in 44 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309516744 and x_2 = 0.7126564030201473
# Converged in 43 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309333315 and x_2 = 0.7126564030199364
# Converged in 43 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309511332 and x_2 = 0.7126564030201411
# Converged in 43 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309644785 and x_2 = 0.7126564030202946
# Converged in 42 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309495243 and x_2 = 0.7126564030201226
# Converged in 42 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309631638 and x_2 = 0.7126564030202794
# Converged in 41 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309467277 and x_2 = 0.7126564030200905
# Converged in 41 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309609498 and x_2 = 0.712656403020254
# Converged in 40 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309425399 and x_2 = 0.7126564030200422
# Converged in 40 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309576745 and x_2 = 0.7126564030202164
# Converged in 39 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309366491 and x_2 = 0.7126564030199746
# Converged in 39 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309530924 and x_2 = 0.7126564030201636
# Converged in 39 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309655525 and x_2 = 0.7126564030203069
# Converged in 38 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309468416 and x_2 = 0.7126564030200917
# Converged in 38 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309607158 and x_2 = 0.7126564030202514
# Converged in 38 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.0898420130971243 and x_2 = 0.7126564030203724
# Converged in 37 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309541812 and x_2 = 0.7126564030201762
# Converged in 37 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130966202 and x_2 = 0.7126564030203144
# Converged in 36 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130945345 and x_2 = 0.7126564030200745
# Converged in 36 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309593792 and x_2 = 0.7126564030202359
# Converged in 36 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130970082 and x_2 = 0.712656403020359
# Converged in 35 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309500774 and x_2 = 0.712656403020129
# Converged in 35 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309629067 and x_2 = 0.7126564030202764
# Converged in 35 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309727058 and x_2 = 0.7126564030203891
# Converged in 34 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309529917 and x_2 = 0.7126564030201625
# Converged in 34 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309650604 and x_2 = 0.7126564030203013
# Converged in 34 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309742941 and x_2 = 0.7126564030204074
# Converged in 33 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309543129 and x_2 = 0.7126564030201777
# Converged in 33 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309660061 and x_2 = 0.7126564030203122
# Converged in 33 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309749679 and x_2 = 0.7126564030204152
# Converged in 32 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309541179 and x_2 = 0.7126564030201754
# Converged in 32 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309657962 and x_2 = 0.7126564030203097
# Converged in 32 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309747636 and x_2 = 0.7126564030204129
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309523401 and x_2 = 0.712656403020155
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309643744 and x_2 = 0.7126564030202934
# Converged in 31 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130973633 and x_2 = 0.7126564030203999
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309807391 and x_2 = 0.7126564030204816
# Converged in 30 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309615587 and x_2 = 0.712656403020261
# Converged in 30 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309714325 and x_2 = 0.7126564030203745
# Converged in 30 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.0898420130979026 and x_2 = 0.7126564030204618
# Converged in 29 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309570042 and x_2 = 0.7126564030202086
# Converged in 29 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130967892 and x_2 = 0.7126564030203338
# Converged in 29 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.0898420130976283 and x_2 = 0.7126564030204302
# Converged in 29 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309827336 and x_2 = 0.7126564030205044
# Converged in 28 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309625556 and x_2 = 0.7126564030202731
# Converged in 28 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309721547 and x_2 = 0.7126564030203839
# Converged in 28 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309795502 and x_2 = 0.7126564030204691
# Converged in 28 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309852333 and x_2 = 0.7126564030205342
# Converged in 27 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309660654 and x_2 = 0.7126564030203143
# Converged in 27 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130974842 and x_2 = 0.7126564030204275
# Converged in 27 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130981579 and x_2 = 0.7126564030205338
# Converged in 27 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309867082 and x_2 = 0.7126564030206548
# Converged in 26 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309685808 and x_2 = 0.7126564030197582
# Converged in 26 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309776209 and x_2 = 0.7126564030192741
# Converged in 26 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309852818 and x_2 = 0.7126564030182915
# Converged in 27 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130995957 and x_2 = 0.7126564030223883
# Converged in 28 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420131003396 and x_2 = 0.7126564030193913
# Converged in 28 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310049982 and x_2 = 0.7126564030183045
# Converged in 29 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310007493 and x_2 = 0.7126564030226483
# Converged in 30 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310048905 and x_2 = 0.7126564030192046
# Converged in 30 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310062821 and x_2 = 0.7126564030180084
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310005986 and x_2 = 0.7126564030229772
# Converged in 32 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310053302 and x_2 = 0.7126564030188687
# Converged in 33 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310013443 and x_2 = 0.7126564030223362
# Converged in 33 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309999348 and x_2 = 0.712656403023562
# Converged in 34 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.0898420131006018 and x_2 = 0.7126564030182723
# Converged in 35 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310006484 and x_2 = 0.7126564030229416
# Converged in 36 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420131005487 and x_2 = 0.712656403018734
# Converged in 37 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310010369 and x_2 = 0.7126564030226038
# Converged in 38 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310052134 and x_2 = 0.7126564030189718
# Converged in 38 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310068078 and x_2 = 0.7126564030175856
# Converged in 39 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309996565 and x_2 = 0.7126564030238042
# Converged in 40 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310066722 and x_2 = 0.7126564030177033
# Converged in 41 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309996538 and x_2 = 0.7126564030238065
# Converged in 42 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310068113 and x_2 = 0.7126564030175825
# Converged in 43 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309993724 and x_2 = 0.7126564030240513
# Converged in 44 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310072497 and x_2 = 0.7126564030172012
# Converged in 46 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310058364 and x_2 = 0.7126564030184301
# Converged in 47 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.0898420131000198 and x_2 = 0.7126564030233333
# Converged in 48 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310065894 and x_2 = 0.7126564030177753
# Converged in 49 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309992171 and x_2 = 0.7126564030241863
# Converged in 51 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310002142 and x_2 = 0.7126564030233192
# Converged in 52 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310067945 and x_2 = 0.712656403017597
# Converged in 53 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309987054 and x_2 = 0.7126564030246312
# Converged in 55 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309994774 and x_2 = 0.7126564030239599
# Converged in 57 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309999885 and x_2 = 0.7126564030235154
# Converged in 58 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310074294 and x_2 = 0.7126564030170449
# Converged in 60 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310070979 and x_2 = 0.7126564030173331
# Converged in 62 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310069356 and x_2 = 0.7126564030174743
# Converged in 64 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310069206 and x_2 = 0.7126564030174872
# Converged in 66 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310070487 and x_2 = 0.7126564030173759
# Converged in 68 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310073321 and x_2 = 0.7126564030171294
# Converged in 70 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310078017 and x_2 = 0.7126564030167211
# Converged in 73 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130999279 and x_2 = 0.7126564030241327
# Converged in 75 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309984641 and x_2 = 0.7126564030248411
# Converged in 78 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420131007597 and x_2 = 0.712656403016899
# Converged in 81 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309988064 and x_2 = 0.7126564030245434
# Converged in 84 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310077583 and x_2 = 0.7126564030167589
# Converged in 87 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309981224 and x_2 = 0.7126564030251383
# Converged in 91 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309985737 and x_2 = 0.7126564030247459
# Converged in 95 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309986642 and x_2 = 0.712656403024667
# Converged in 99 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309984195 and x_2 = 0.7126564030248798
# Converged in 103 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309977902 and x_2 = 0.7126564030254272
# Converged in 108 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310085128 and x_2 = 0.7126564030161028
# Converged in 114 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310079253 and x_2 = 0.7126564030166137
# Converged in 119 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309975182 and x_2 = 0.7126564030256636
# Converged in 126 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310083688 and x_2 = 0.712656403016228
# Converged in 133 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309977956 and x_2 = 0.7126564030254225
# Converged in 141 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130997774 and x_2 = 0.7126564030254411
# Converged in 150 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310085753 and x_2 = 0.7126564030160484
# Converged in 160 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310086744 and x_2 = 0.7126564030159622
# Converged in 171 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309973207 and x_2 = 0.7126564030258353
# Converged in 184 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310091479 and x_2 = 0.7126564030155506
# Converged in 199 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309970648 and x_2 = 0.712656403026058
# Converged in 217 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309971673 and x_2 = 0.7126564030259688
# Converged in 238 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310093123 and x_2 = 0.7126564030154076
# Converged in 264 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310091262 and x_2 = 0.7126564030155693
# Converged in 295 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309969453 and x_2 = 0.712656403026162
# Converged in 335 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309969679 and x_2 = 0.7126564030261422
# Converged in 387 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309969145 and x_2 = 0.7126564030261886
# Converged in 457 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.089842013099663 and x_2 = 0.7126564030264362
# Converged in 559 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309966236 and x_2 = 0.7126564030264417
# Converged in 718 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310098931 and x_2 = 0.7126564030149025
# Converged in 1004 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310098687 and x_2 = 0.7126564030149237
# Converged in 1662 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310100548 and x_2 = 0.7126564030147619
# Converged in 4823 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309962436 and x_2 = 0.712656403026772
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge

# %%
font = {'size': 18}
matplotlib.rc('font', **font)


fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(eta_path, stepsize_path)
ax1.set_xlabel('eta')
ax1.set_ylabel('number_of_steps')
# Out:
# Text(0, 0.5, 'number_of_steps')

# %%
import time

run_time = []
step_size = [] 

for j in range(1,1000):
    r = j/2000
    time_run = 0
    start_time = time.clock()
    solver.find_min(x_1_init =1, x_2_init = 1, n_iter = 100000, eta = r, tol = tolerance)
    time_run = time.clock() - start_time
    if solver.g_x1 > tolerance or  solver.g_x2 > tolerance :
      break
    step_size.append(r)
    run_time.append(time_run)
# Out:
# Converged in 6674 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308738571 and x_2 = 0.7126564030192525
# Converged in 3332 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308743137 and x_2 = 0.7126564030192576
# Converged in 2218 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308747783 and x_2 = 0.7126564030192628
# Converged in 1661 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308752503 and x_2 = 0.7126564030192685
# Converged in 1327 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308762223 and x_2 = 0.7126564030192797
# Converged in 1104 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308762153 and x_2 = 0.7126564030192796
# Converged in 945 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308772005 and x_2 = 0.712656403019291
# Converged in 826 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308791605 and x_2 = 0.7126564030193133
# Converged in 733 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130879181 and x_2 = 0.7126564030193135
# Converged in 659 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308811361 and x_2 = 0.7126564030193361
# Converged in 598 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308806951 and x_2 = 0.7126564030193311
# Converged in 547 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308792875 and x_2 = 0.7126564030193149
# Converged in 505 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308850577 and x_2 = 0.7126564030193813
# Converged in 468 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308841885 and x_2 = 0.7126564030193713
# Converged in 436 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.089842013088379 and x_2 = 0.7126564030193665
# Converged in 408 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308833963 and x_2 = 0.7126564030193622
# Converged in 384 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130888601 and x_2 = 0.7126564030194219
# Converged in 362 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308882457 and x_2 = 0.7126564030194179
# Converged in 342 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308851027 and x_2 = 0.7126564030193818
# Converged in 325 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201308911878 and x_2 = 0.7126564030194519
# Converged in 309 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308913141 and x_2 = 0.7126564030194532
# Converged in 294 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201308868729 and x_2 = 0.7126564030194023
# Converged in 281 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308897802 and x_2 = 0.7126564030194356
# Converged in 269 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.0898420130891739 and x_2 = 0.712656403019458
# Converged in 258 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308941206 and x_2 = 0.7126564030194855
# Converged in 247 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308865324 and x_2 = 0.7126564030193983
# Converged in 238 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201308935762 and x_2 = 0.7126564030194793
# Converged in 229 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308924158 and x_2 = 0.7126564030194659
# Converged in 221 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308961495 and x_2 = 0.7126564030195089
# Converged in 213 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308928026 and x_2 = 0.7126564030194703
# Converged in 206 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308961175 and x_2 = 0.7126564030195085
# Converged in 199 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130893222 and x_2 = 0.7126564030194752
# Converged in 193 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308987216 and x_2 = 0.7126564030195385
# Converged in 187 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308989521 and x_2 = 0.712656403019541
# Converged in 181 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308939134 and x_2 = 0.7126564030194831
# Converged in 176 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308994373 and x_2 = 0.7126564030195466
# Converged in 171 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309005457 and x_2 = 0.7126564030195593
# Converged in 166 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308973509 and x_2 = 0.7126564030195226
# Converged in 162 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309064554 and x_2 = 0.7126564030196273
# Converged in 157 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308952355 and x_2 = 0.7126564030194983
# Converged in 153 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308973107 and x_2 = 0.7126564030195223
# Converged in 149 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308958246 and x_2 = 0.7126564030195051
# Converged in 146 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309091958 and x_2 = 0.7126564030196588
# Converged in 142 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309017041 and x_2 = 0.7126564030195728
# Converged in 139 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130909419 and x_2 = 0.7126564030196614
# Converged in 136 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309143611 and x_2 = 0.7126564030197182
# Converged in 132 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201308978977 and x_2 = 0.7126564030195289
# Converged in 129 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308978025 and x_2 = 0.7126564030195278
# Converged in 127 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309153513 and x_2 = 0.7126564030197295
# Converged in 124 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309111017 and x_2 = 0.7126564030196807
# Converged in 121 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309041254 and x_2 = 0.7126564030196005
# Converged in 119 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309156613 and x_2 = 0.7126564030197332
# Converged in 116 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309044701 and x_2 = 0.7126564030196045
# Converged in 114 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309125887 and x_2 = 0.7126564030196979
# Converged in 112 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309186333 and x_2 = 0.7126564030197674
# Converged in 110 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309229306 and x_2 = 0.7126564030198168
# Converged in 107 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130903984 and x_2 = 0.7126564030195989
# Converged in 105 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309052747 and x_2 = 0.7126564030196137
# Converged in 103 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309048649 and x_2 = 0.7126564030196091
# Converged in 102 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309258735 and x_2 = 0.7126564030198506
# Converged in 100 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309231926 and x_2 = 0.7126564030198198
# Converged in 98 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309189473 and x_2 = 0.712656403019771
# Converged in 96 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309128882 and x_2 = 0.7126564030197013
# Converged in 95 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309288699 and x_2 = 0.7126564030198851
# Converged in 93 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309210343 and x_2 = 0.7126564030197949
# Converged in 91 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309107125 and x_2 = 0.7126564030196763
# Converged in 90 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309244574 and x_2 = 0.7126564030198344
# Converged in 88 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309117344 and x_2 = 0.712656403019688
# Converged in 87 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309236511 and x_2 = 0.7126564030198251
# Converged in 86 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309334486 and x_2 = 0.7126564030199377
# Converged in 84 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309184181 and x_2 = 0.7126564030197649
# Converged in 83 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309272234 and x_2 = 0.7126564030198662
# Converged in 82 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130934542 and x_2 = 0.7126564030199503
# Converged in 80 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309157908 and x_2 = 0.7126564030197347
# Converged in 79 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309224307 and x_2 = 0.712656403019811
# Converged in 78 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309279233 and x_2 = 0.7126564030198742
# Converged in 77 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309324333 and x_2 = 0.712656403019926
# Converged in 76 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309360912 and x_2 = 0.7126564030199681
# Converged in 75 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309389993 and x_2 = 0.7126564030200015
# Converged in 73 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309137571 and x_2 = 0.7126564030197112
# Converged in 72 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309156155 and x_2 = 0.7126564030197327
# Converged in 71 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309166592 and x_2 = 0.7126564030197446
# Converged in 70 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309169106 and x_2 = 0.7126564030197475
# Converged in 69 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309163703 and x_2 = 0.7126564030197413
# Converged in 69 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309438021 and x_2 = 0.7126564030200568
# Converged in 68 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309426602 and x_2 = 0.7126564030200437
# Converged in 67 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309409177 and x_2 = 0.7126564030200236
# Converged in 66 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309385191 and x_2 = 0.7126564030199961
# Converged in 65 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309353876 and x_2 = 0.71265640301996
# Converged in 64 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130931421 and x_2 = 0.7126564030199144
# Converged in 63 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130926486 and x_2 = 0.7126564030198577
# Converged in 62 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309204101 and x_2 = 0.7126564030197878
# Converged in 62 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130945197 and x_2 = 0.7126564030200728
# Converged in 61 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309397398 and x_2 = 0.7126564030200101
# Converged in 60 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309330757 and x_2 = 0.7126564030199335
# Converged in 59 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309249311 and x_2 = 0.7126564030198398
# Converged in 59 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309478254 and x_2 = 0.712656403020103
# Converged in 58 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309405128 and x_2 = 0.712656403020019
# Converged in 57 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309315033 and x_2 = 0.7126564030199154
# Converged in 57 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130952164 and x_2 = 0.712656403020153
# Converged in 56 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309439765 and x_2 = 0.7126564030200588
# Converged in 55 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309337511 and x_2 = 0.7126564030199412
# Converged in 55 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309534492 and x_2 = 0.7126564030201678
# Converged in 54 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309439858 and x_2 = 0.712656403020059
# Converged in 53 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309319616 and x_2 = 0.7126564030199206
# Converged in 53 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309518296 and x_2 = 0.7126564030201491
# Converged in 52 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130940449 and x_2 = 0.7126564030200182
# Converged in 52 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201309578418 and x_2 = 0.7126564030202183
# Converged in 51 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309469289 and x_2 = 0.7126564030200928
# Converged in 50 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309326068 and x_2 = 0.712656403019928
# Converged in 50 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309518146 and x_2 = 0.712656403020149
# Converged in 49 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309377035 and x_2 = 0.7126564030199867
# Converged in 49 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309554005 and x_2 = 0.7126564030201902
# Converged in 48 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309412823 and x_2 = 0.7126564030200279
# Converged in 48 steps.  Loss fn = -1.0316284534898779 achieved by x_1 = -0.08984201309578912 and x_2 = 0.7126564030202188
# Converged in 47 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309435375 and x_2 = 0.7126564030200537
# Converged in 47 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309594211 and x_2 = 0.7126564030202365
# Converged in 46 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309445819 and x_2 = 0.7126564030200658
# Converged in 46 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309600652 and x_2 = 0.7126564030202438
# Converged in 45 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309444555 and x_2 = 0.7126564030200643
# Converged in 45 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309598455 and x_2 = 0.7126564030202414
# Converged in 44 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309431276 and x_2 = 0.7126564030200491
# Converged in 44 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309587314 and x_2 = 0.7126564030202285
# Converged in 43 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309404914 and x_2 = 0.7126564030200186
# Converged in 43 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130956635 and x_2 = 0.7126564030202044
# Converged in 42 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309363489 and x_2 = 0.7126564030199711
# Converged in 42 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309533989 and x_2 = 0.7126564030201672
# Converged in 42 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309661771 and x_2 = 0.7126564030203141
# Converged in 41 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309487767 and x_2 = 0.712656403020114
# Converged in 41 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309626061 and x_2 = 0.712656403020273
# Converged in 40 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309424007 and x_2 = 0.7126564030200407
# Converged in 40 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309576934 and x_2 = 0.7126564030202165
# Converged in 40 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309692105 and x_2 = 0.712656403020349
# Converged in 39 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309510177 and x_2 = 0.7126564030201398
# Converged in 39 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309640846 and x_2 = 0.7126564030202901
# Converged in 38 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309419598 and x_2 = 0.7126564030200356
# Converged in 38 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309571237 and x_2 = 0.71265640302021
# Converged in 38 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309686057 and x_2 = 0.712656403020342
# Converged in 37 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130947613 and x_2 = 0.7126564030201007
# Converged in 37 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309613024 and x_2 = 0.712656403020258
# Converged in 37 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309716874 and x_2 = 0.7126564030203775
# Converged in 36 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309511919 and x_2 = 0.7126564030201418
# Converged in 36 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309639234 and x_2 = 0.7126564030202882
# Converged in 36 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309736012 and x_2 = 0.7126564030203995
# Converged in 35 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.0898420130952984 and x_2 = 0.7126564030201624
# Converged in 35 steps.  Loss fn = -1.0316284534898779 achieved by x_1 = -0.0898420130965195 and x_2 = 0.7126564030203029
# Converged in 35 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309744974 and x_2 = 0.7126564030204098
# Converged in 34 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309530972 and x_2 = 0.7126564030201638
# Converged in 34 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309651896 and x_2 = 0.7126564030203028
# Converged in 34 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309744237 and x_2 = 0.7126564030204089
# Converged in 33 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130951465 and x_2 = 0.7126564030201449
# Converged in 33 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130963845 and x_2 = 0.7126564030202873
# Converged in 33 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309733243 and x_2 = 0.7126564030203963
# Converged in 33 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309805673 and x_2 = 0.7126564030204796
# Converged in 32 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309609417 and x_2 = 0.7126564030202539
# Converged in 32 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309710199 and x_2 = 0.7126564030203698
# Converged in 32 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309787437 and x_2 = 0.7126564030204587
# Converged in 31 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309560434 and x_2 = 0.7126564030201973
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309671598 and x_2 = 0.7126564030203248
# Converged in 31 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130975709 and x_2 = 0.7126564030204227
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130982271 and x_2 = 0.7126564030204969
# Converged in 30 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309611053 and x_2 = 0.7126564030202698
# Converged in 30 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309709307 and x_2 = 0.7126564030203957
# Converged in 30 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309784863 and x_2 = 0.7126564030205059
# Converged in 30 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309842703 and x_2 = 0.7126564030206142
# Converged in 29 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309641406 and x_2 = 0.7126564030198463
# Converged in 29 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309736348 and x_2 = 0.712656403019645
# Converged in 29 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130981259 and x_2 = 0.7126564030192395
# Converged in 29 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309875647 and x_2 = 0.7126564030185581
# Converged in 30 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309970159 and x_2 = 0.7126564030219147
# Converged in 30 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309974497 and x_2 = 0.7126564030225595
# Converged in 31 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310035403 and x_2 = 0.7126564030196166
# Converged in 31 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310042055 and x_2 = 0.7126564030192447
# Converged in 31 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310046308 and x_2 = 0.7126564030190293
# Converged in 31 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310042982 and x_2 = 0.7126564030194341
# Converged in 30 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310042364 and x_2 = 0.712656403019057
# Converged in 33 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420131001556 and x_2 = 0.7126564030221335
# Converged in 34 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310055798 and x_2 = 0.7126564030186491
# Converged in 35 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310002222 and x_2 = 0.7126564030233113
# Converged in 36 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310065447 and x_2 = 0.712656403017814
# Converged in 38 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420131004998 and x_2 = 0.7126564030191593
# Converged in 39 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310011909 and x_2 = 0.7126564030224698
# Converged in 40 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.089842013100534 and x_2 = 0.7126564030188619
# Converged in 41 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310008462 and x_2 = 0.7126564030227697
# Converged in 42 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310057012 and x_2 = 0.7126564030185476
# Converged in 43 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310004601 and x_2 = 0.7126564030231054
# Converged in 44 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310061139 and x_2 = 0.7126564030181889
# Converged in 45 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310000262 and x_2 = 0.7126564030234828
# Converged in 46 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310065536 and x_2 = 0.7126564030178064
# Converged in 47 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309996122 and x_2 = 0.7126564030238428
# Converged in 48 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310068861 and x_2 = 0.7126564030175172
# Converged in 49 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.0898420130999455 and x_2 = 0.7126564030239795
# Converged in 50 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310067134 and x_2 = 0.7126564030176676
# Converged in 51 steps.  Loss fn = -1.031628453489877 achieved by x_1 = -0.08984201310002046 and x_2 = 0.7126564030233277
# Converged in 51 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310001724 and x_2 = 0.7126564030233555
# Converged in 47 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310071854 and x_2 = 0.712656403017257
# Converged in 54 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201309996465 and x_2 = 0.7126564030238128
# Converged in 57 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420131006544 and x_2 = 0.712656403017815
# Converged in 59 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310070584 and x_2 = 0.7126564030173674
# Converged in 61 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201310070043 and x_2 = 0.7126564030174146
# Converged in 63 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310063761 and x_2 = 0.712656403017961
# Converged in 63 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310074583 and x_2 = 0.7126564030170198
# Converged in 59 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309986106 and x_2 = 0.7126564030247138
# Converged in 68 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310071435 and x_2 = 0.7126564030172934
# Converged in 71 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309991671 and x_2 = 0.7126564030242296
# Converged in 70 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = -0.08984201310068753 and x_2 = 0.7126564030175268
# Converged in 76 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309989683 and x_2 = 0.7126564030244027
# Converged in 77 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201309990457 and x_2 = 0.7126564030243354
# Converged in 83 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.08984201310072511 and x_2 = 0.7126564030172
# Converged in 86 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.0898420131007835 and x_2 = -0.7126564030166921
# Converged in 87 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309987325 and x_2 = -0.7126564030246078
# Converged in 89 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.0898420131007837 and x_2 = -0.7126564030166905
# Converged in 89 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = 0.08984201309986113 and x_2 = -0.7126564030247131
# Converged in 94 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = 0.0898420131008292 and x_2 = -0.7126564030162947
# Converged in 89 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201309981668 and x_2 = -0.7126564030250996
# Converged in 100 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309982379 and x_2 = -0.7126564030250379
# Converged in 105 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310081716 and x_2 = -0.7126564030163994
# Converged in 108 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.0898420130998279 and x_2 = -0.712656403025002
# Converged in 105 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310081255 and x_2 = -0.7126564030164396
# Converged in 115 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = 0.08984201309978257 and x_2 = -0.7126564030253962
# Converged in 124 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201310080837 and x_2 = -0.7126564030164759
# Converged in 131 steps.  Loss fn = -1.031628453489877 achieved by x_1 = 0.08984201309982037 and x_2 = -0.7126564030250675
# Converged in 137 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201309975362 and x_2 = -0.7126564030256479
# Converged in 144 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = 0.089842013100823 and x_2 = -0.7126564030163487
# Converged in 149 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201309980404 and x_2 = -0.7126564030252094
# Converged in 144 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310091303 and x_2 = -0.7126564030155659
# Converged in 165 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310091593 and x_2 = -0.7126564030155406
# Converged in 182 steps.  Loss fn = -1.031628453489877 achieved by x_1 = 0.08984201309972886 and x_2 = -0.7126564030258634
# Converged in 198 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309971919 and x_2 = -0.7126564030259476
# Converged in 215 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201310093809 and x_2 = -0.7126564030153478
# Converged in 235 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201310090739 and x_2 = -0.7126564030156148
# Converged in 257 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = 0.08984201310094385 and x_2 = -0.7126564030152978
# Converged in 284 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309970384 and x_2 = -0.7126564030260808
# Converged in 316 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309968995 and x_2 = -0.7126564030262017
# Converged in 355 steps.  Loss fn = -1.0316284534898776 achieved by x_1 = 0.0898420131009662 and x_2 = -0.7126564030151036
# Converged in 404 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309968858 and x_2 = -0.7126564030262137
# Converged in 459 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201310097338 and x_2 = -0.7126564030150411
# Converged in 543 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309966307 and x_2 = -0.7126564030264355
# Converged in 742 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310098659 and x_2 = -0.7126564030149262
# Converged in 1055 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = 0.08984201309964837 and x_2 = -0.7126564030265633
# Converged in 1750 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310100595 and x_2 = -0.7126564030147579
# Converged in 5010 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = 0.08984201310101074 and x_2 = -0.7126564030147162
# Did not converge

# %%
font = {'size': 18}
matplotlib.rc('font', **font)


fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(step_size, run_time)
ax1.set_xlabel('eta')
ax1.set_ylabel('Time taken for convergence')
# Out:
# Text(0, 0.5, 'Time taken for convergence')

# %%
font = {'size': 18}
matplotlib.rc('font', **font)

fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(1, 1, 1)
eta = [0.000005, 0.00005, 0.0005, 0.005, 0.05]
for r in eta :
    solver.find_min(x_1_init =0.5, x_2_init = 0.5, n_iter = 50000, eta = r, tol = tolerance)
    x_range = range(len(solver.loss_path))
    ax1.scatter(x_range, solver.loss_path)      
#ax1.scatter(x_range, solver.loss_path)
plt.xlim((0,2000))
ax1.legend(eta)
ax1.set_xlabel('Number of steps')
ax1.set_ylabel('Loss path')
# Out:
# Did not converge
# Did not converge
# Converged in 6397 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201308735218 and x_2 = 0.7126564030192485
# Converged in 631 steps.  Loss fn = -1.0316284534898774 achieved by x_1 = -0.0898420130880547 and x_2 = 0.7126564030193294
# Converged in 53 steps.  Loss fn = -1.0316284534898772 achieved by x_1 = -0.08984201309241517 and x_2 = 0.7126564030198309
# Text(0, 0.5, 'Loss path')
