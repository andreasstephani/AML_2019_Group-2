# %% [markdown]
# <a href="https://colab.research.google.com/github/andreasstephani/AML_2019_Group-2/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Coursework Part 1

# %% [markdown]
# ##Gradient Descent

# %% [markdown]
# ###Why is gradient descent important in machine learning?
#
# Gradient descent is an optimization technique which can be used to minimise a function. This is a very important and useful tool in machine learning. Machine Learning models have a cost function, which is a way to determine how well the model has performed given the different values of each of its parameters. Therefore, gradient descent can be used to find the parameter values that minimise the cost function of the model (i.e. find the parameters that give the lowest cost). An example can be a linear regression model where the parameters are the beta coefficients and the cost function is the mean squared error (MSE). Thus, gradient descent could be used to find the beta coefficients that minimise the MSE of the linear regression model.

# %% [markdown]
# ###How does plain vanilla gradient descent work?
#
# Plain vanilla gradient descent can be used to minimise a function (i.e. find the minimum point of the function). The procedure of doing this starts by choosing a starting point that lies within the domain of the chosen function. The very first step is usually a downhill movement from the starting point towards the direction specified by the gradient at that point. Then, the gradient at the new point is recalculated, and another step is taken in the direction that it specifies. This process is repeated until the global minimum of the function or a point where no more downhill movement can be made (i.e. a local minimum) is reached.

# %% [markdown]
# ##Gradient descent class

# %%
import numpy as np

class gd_andreas_2d:
    
    def __init__(self, fn_loss, fn_grad1, fn_grad2):
        self.fn_loss = fn_loss
        self.fn_grad1 = fn_grad1
        self.fn_grad2 = fn_grad2
        
    def find_min(self, x_1_init,x_2_init, n_iter, eta, tol):
        #self.x_1_init = x_1_init
        #self.x_2_init = x_2_init
        #self.n_iter = n_iter
        #self.eta = eta
        #self.tol = tol
        
        x_1 = x_1_init
        x_2 = x_2_init
        
        loss_path = []
        x_1_path = []
        x_2_path = []
        
        x_1_path.append(x_1)
        x_2_path.append(x_2)
        loss_this = self.fn_loss(x_1,x_2)
        loss_path.append(loss_this)
        g1 = self.fn_grad1(x_1,x_2)
        g2 = self.fn_grad2(x_1,x_2)

        for i in range(n_iter):
            if (np.abs(g1) < tol and np.abs(g2) < tol) or np.isnan(g1) or np.isnan(g2):
                break
            g1 = self.fn_grad1(x_1,x_2)
            g2 = self.fn_grad2(x_1,x_2)
            x_1 += -eta * g1
            x_2 += -eta * g2
            x_1_path.append(x_1)
            x_2_path.append(x_2)
            loss_this = self.fn_loss(x_1,x_2)
            loss_path.append(loss_this)
            
        if np.isnan(g1) or np.isnan(g2):
            print('Exploded')
        elif np.abs(g1) > tol or np.abs(g2) > tol:
            print('Did not converge')
        else:
            print('Converged in {} steps.  Loss fn = {} achieved by x_1 = {} and x_2 = {}'.format(i+1, loss_this, x_1,x_2))
        
        self.loss_path = loss_path
        self.x1_path = x_1_path
        self.x2_path = x_2_path
        self.loss_fn_min = loss_this
        self.x1_at_min = x_1
        self.x2_at_min = x_2
        self.g_x1 = g1
        self.g_x2 = g2
        self.num_step = i+1
      
    
    def momentum(self, x_1_init, x_2_init, n_iter, eta, tol, alpha):
        
        x_1 = x_1_init
        x_2 = x_2_init
        
        loss_path = []
        x_1_path = []
        x_2_path = []
        
        x_1_path.append(x_1)
        x_2_path.append(x_2)
        loss_this = self.fn_loss(x_1,x_2)
        loss_path.append(loss_this)
        g1 = self.fn_grad1(x_1,x_2)
        g2 = self.fn_grad2(x_1,x_2)
        nu_1 = 0
        nu_2 = 0

        for i in range(n_iter):
            g1 = self.fn_grad1(x_1,x_2)
            g2 = self.fn_grad2(x_1,x_2)
            if (np.abs(g1) < tol and np.abs(g2) < tol) or np.isnan(g1) or np.isnan(g2):
                break

            nu_1 = alpha * nu_1 + eta * g1
            nu_2 = alpha * nu_2 + eta * g2
            x_1 += -nu_1
            x_2 += -nu_2
            x_1_path.append(x_1)
            x_2_path.append(x_2)
            loss_this = self.fn_loss(x_1,x_2)
            loss_path.append(loss_this)

        if np.isnan(g1) or np.isnan(g2):
            print('Exploded')
        elif np.abs(g1) > tol or np.abs(g2) > tol:
            print('Did not converge')
        else:
            print('Converged in {} steps.  Loss fn = {} achieved by x_1 = {} and x_2 = {}'.format(i+1, loss_this, x_1,x_2))
        
        self.loss_path = loss_path
        self.x1_path = x_1_path
        self.x2_path = x_2_path
        self.loss_fn_min_momentum = loss_this
        self.x1_at_min_momentum = x_1
        self.x2_at_min_momentum = x_2
        self.g_x1 = g1
        self.g_x2 = g2
        self.num_step = i+1
       

    def nag(self, x_1_init, x_2_init, n_iter, eta, tol, alpha):
        x_1 = x_1_init
        x_2 = x_2_init
        
        loss_path = []
        x_1_path = []
        x_2_path = []
        
        x_1_path.append(x_1)
        x_2_path.append(x_2)
        loss_this = self.fn_loss(x_1,x_2)
        loss_path.append(loss_this)
        g1 = self.fn_grad1(x_1,x_2)
        g2 = self.fn_grad2(x_1,x_2)
        nu_1 = 0
        nu_2 = 0

        for i in range(n_iter):
            # i starts from 0 so add 1
            # The formula for mu was mentioned by David Barber UCL as being Nesterovs suggestion
            mu = 1 - 3 / (i + 1 + 5) 
            g1 = self.fn_grad1(x_1 - mu*nu_1,x_2 - mu*nu_1)
            g2 = self.fn_grad2(x_2 - mu*nu_2,x_2 - mu*nu_2)
     
            if (np.abs(g1) < tol and np.abs(g2) < tol) or np.isnan(g1) or np.isnan(g2):
                break

            nu_1 = alpha * nu_1 + eta * g1
            nu_2 = alpha * nu_2 + eta * g2
            x_1 += -nu_1
            x_2 += -nu_2
            x_1_path.append(x_1)
            x_2_path.append(x_2)
            loss_this = self.fn_loss(x_1,x_2)
            loss_path.append(loss_this)

        if np.isnan(g1) or np.isnan(g2):
            print('Exploded')
        elif np.abs(g1) > tol or np.abs(g2) > tol:
            print('Did not converge')
        else:
            print('Converged in {} steps.  Loss fn = {} achieved by x_1 = {} and x_2 ={}'.format(i+1, loss_this, x_1,x_2))
        self.loss_path = loss_path
        self.x1_path = x_1_path
        self.x2_path = x_2_path
        self.loss_fn_min_nag = loss_this
        self.x1_at_min_nag = x_1
        self.x2_at_min_nag = x_2
        self.g_x1 = g1
        self.g_x2 = g2
        self.num_step = i+1

# %%
def fn_loss(x_1,x_2):
    return (4*x_1**2) - 2.1*x_1**4 + (x_1**6)/3 + x_1*x_2 - 4*x_2**2 + 4*x_2**4
    
def fn_grad1(x_1,x_2):
    return 8*x_1 - 8.4*x_1**3 + 2*x_1**5 + x_2
    
def fn_grad2(x_1,x_2): 
    return x_1 - 8*x_2 + 16*x_2**3

# %%
solver = gd_andreas_2d(fn_loss = fn_loss, fn_grad1 = fn_grad1, fn_grad2 = fn_grad2)

# %%
solver.find_min(x_1_init=1, x_2_init=1, n_iter = 10000, eta= 0.001, tol=1e-5)
# Out:
# Converged in 1839 steps.  Loss fn = -1.031628453483402 achieved by x_1 = -0.08984072319727252 and x_2 = 0.7126562546861168

# %%
solver.momentum(x_1_init = 1, x_2_init = 1, n_iter = 1000, eta = 0.001, tol = 1e-5, alpha=0.90)
# Out:
# Converged in 258 steps.  Loss fn -1.0316284534849685 achieved by x_1 = -0.08984308295044065 and x_2 = 0.7126567109023105

# %%
solver.nag(x_1_init = 1, x_2_init = 1, n_iter = 10000, eta = 0.001, tol = 1e-5, alpha=0.995)
# Out:
# Converged in 1153 steps.  Loss fn -0.04249454279124776 achieved by x_1 = 1.6964054050173616 and x_2 =-0.6614388591248741

# %%
import matplotlib
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
# %matplotlib inline

font = {'size': 18}
matplotlib.rc('font', **font)

fig = plt.figure(figsize=(15,15))
ax = plt.axes(projection="3d")

z_points = solver.loss_path
x_points = solver.x1_path
y_points = solver.x2_path
ax.scatter3D(x_points, y_points, z_points,c=z_points);
ax.set_xlabel('x_1')
ax.set_ylabel('x_2')
ax.set_zlabel('loss')
plt.show()

# %%
eta_path=[]
stepsize_path=[]

for j in range (1,1000):
  r=(j/2000)
  solver.find_min(x_1_init=1, x_2_init=1, n_iter = 10000, eta=r, tol=1e-5)
  if solver
  eta_path.append(r)
  stepsize_path.append(solver.num_step)
# Out:
# Converged in 3682 steps.  Loss fn = -1.031628453483344 achieved by x_1 = -0.08984071746667992 and x_2 = 0.7126562540271034
# Converged in 1839 steps.  Loss fn = -1.031628453483402 achieved by x_1 = -0.08984072319727252 and x_2 = 0.7126562546861168
# Converged in 1225 steps.  Loss fn = -1.0316284534835087 achieved by x_1 = -0.08984073391097261 and x_2 = 0.7126562559181732
# Converged in 918 steps.  Loss fn = -1.0316284534836149 achieved by x_1 = -0.08984074461145354 and x_2 = 0.7126562571487091
# Converged in 734 steps.  Loss fn = -1.0316284534837676 achieved by x_1 = -0.08984076016719458 and x_2 = 0.7126562589375861
# Converged in 611 steps.  Loss fn = -1.031628453483824 achieved by x_1 = -0.08984076597096412 and x_2 = 0.7126562596050128
# Converged in 523 steps.  Loss fn = -1.031628453483834 achieved by x_1 = -0.08984076696257197 and x_2 = 0.7126562597190539
# Converged in 457 steps.  Loss fn = -1.0316284534838438 achieved by x_1 = -0.08984076799243752 and x_2 = 0.7126562598374943
# Converged in 406 steps.  Loss fn = -1.0316284534839937 achieved by x_1 = -0.08984078356488151 and x_2 = 0.7126562616282904
# Converged in 365 steps.  Loss fn = -1.0316284534840503 achieved by x_1 = -0.0898407894900242 and x_2 = 0.7126562623096735
# Converged in 331 steps.  Loss fn = -1.0316284534838758 achieved by x_1 = -0.08984077131497346 and x_2 = 0.7126562602196026
# Converged in 303 steps.  Loss fn = -1.0316284534838875 achieved by x_1 = -0.0898407725012591 and x_2 = 0.7126562603560305
# Converged in 280 steps.  Loss fn = -1.0316284534843085 achieved by x_1 = -0.08984081690931314 and x_2 = 0.7126562654628374
# Converged in 260 steps.  Loss fn = -1.031628453484536 achieved by x_1 = -0.08984084157413648 and x_2 = 0.7126562682992279
# Converged in 242 steps.  Loss fn = -1.0316284534843332 achieved by x_1 = -0.08984081956388647 and x_2 = 0.712656265768121
# Converged in 227 steps.  Loss fn = -1.0316284534846445 achieved by x_1 = -0.08984085357761265 and x_2 = 0.7126562696796067
# Converged in 213 steps.  Loss fn = -1.031628453484403 achieved by x_1 = -0.08984082709811642 and x_2 = 0.7126562666345502
# Converged in 201 steps.  Loss fn = -1.0316284534845028 achieved by x_1 = -0.08984083796152599 and x_2 = 0.7126562678838173
# Converged in 190 steps.  Loss fn = -1.031628453484387 achieved by x_1 = -0.08984082535298946 and x_2 = 0.7126562664338802
# Converged in 181 steps.  Loss fn = -1.0316284534850202 achieved by x_1 = -0.08984089592540144 and x_2 = 0.712656274549502
# Converged in 172 steps.  Loss fn = -1.0316284534849165 achieved by x_1 = -0.08984088407716087 and x_2 = 0.7126562731869966
# Converged in 164 steps.  Loss fn = -1.0316284534849705 achieved by x_1 = -0.08984089025975538 and x_2 = 0.7126562738979825
# Converged in 157 steps.  Loss fn = -1.0316284534852904 achieved by x_1 = -0.08984092746490038 and x_2 = 0.7126562781764655
# Converged in 150 steps.  Loss fn = -1.031628453485079 achieved by x_1 = -0.08984090270602087 and x_2 = 0.7126562753292767
# Converged in 144 steps.  Loss fn = -1.0316284534852838 achieved by x_1 = -0.08984092666115692 and x_2 = 0.7126562780840487
# Converged in 138 steps.  Loss fn = -1.0316284534850322 achieved by x_1 = -0.08984089734359027 and x_2 = 0.7126562747126253
# Converged in 133 steps.  Loss fn = -1.0316284534853521 achieved by x_1 = -0.08984093477355597 and x_2 = 0.71265627901696
# Converged in 128 steps.  Loss fn = -1.0316284534852942 achieved by x_1 = -0.08984092791658793 and x_2 = 0.7126562782284355
# Converged in 123 steps.  Loss fn = -1.031628453484842 achieved by x_1 = -0.08984087563126307 and x_2 = 0.7126562722157923
# Converged in 119 steps.  Loss fn = -1.0316284534851765 achieved by x_1 = -0.08984091409312461 and x_2 = 0.7126562766387912
# Converged in 115 steps.  Loss fn = -1.031628453485194 achieved by x_1 = -0.08984091613610591 and x_2 = 0.7126562768737327
# Converged in 111 steps.  Loss fn = -1.0316284534848956 achieved by x_1 = -0.08984088172712325 and x_2 = 0.7126562729168135
# Converged in 108 steps.  Loss fn = -1.0316284534855613 achieved by x_1 = -0.08984096000567439 and x_2 = 0.712656281918603
# Converged in 105 steps.  Loss fn = -1.031628453485951 achieved by x_1 = -0.0898410087029912 and x_2 = 0.7126562875186414
# Converged in 102 steps.  Loss fn = -1.0316284534861266 achieved by x_1 = -0.08984103137813321 and x_2 = 0.7126562901262128
# Converged in 99 steps.  Loss fn = -1.0316284534861124 achieved by x_1 = -0.0898410295747327 and x_2 = 0.7126562899188313
# Converged in 96 steps.  Loss fn = -1.0316284534859068 achieved by x_1 = -0.08984100299508928 and x_2 = 0.7126562868622632
# Converged in 93 steps.  Loss fn = -1.0316284534854743 achieved by x_1 = -0.08984094944184547 and x_2 = 0.7126562807038187
# Converged in 91 steps.  Loss fn = -1.031628453486166 achieved by x_1 = -0.08984103657598641 and x_2 = 0.7126562907239635
# Converged in 88 steps.  Loss fn = -1.031628453485366 achieved by x_1 = -0.08984093644446178 and x_2 = 0.7126562792091703
# Converged in 86 steps.  Loss fn = -1.0316284534857811 achieved by x_1 = -0.08984098718684903 and x_2 = 0.7126562850443828
# Converged in 84 steps.  Loss fn = -1.0316284534860334 achieved by x_1 = -0.08984101926929118 and x_2 = 0.7126562887337612
# Converged in 82 steps.  Loss fn = -1.031628453486148 achieved by x_1 = -0.08984103421903125 and x_2 = 0.7126562904529351
# Converged in 80 steps.  Loss fn = -1.0316284534861366 achieved by x_1 = -0.089841032682049 and x_2 = 0.7126562902761905
# Converged in 78 steps.  Loss fn = -1.0316284534859963 achieved by x_1 = -0.0898410144683059 and x_2 = 0.712656288181674
# Converged in 76 steps.  Loss fn = -1.0316284534857119 achieved by x_1 = -0.08984097852595026 and x_2 = 0.7126562840484261
# Converged in 75 steps.  Loss fn = -1.0316284534867706 achieved by x_1 = -0.08984111966810147 and x_2 = 0.7126563002793018
# Converged in 73 steps.  Loss fn = -1.0316284534863402 achieved by x_1 = -0.08984105975034892 and x_2 = 0.7126562933889662
# Converged in 71 steps.  Loss fn = -1.0316284534857083 achieved by x_1 = -0.0898409780831062 and x_2 = 0.7126562839975107
# Converged in 70 steps.  Loss fn = -1.0316284534865559 achieved by x_1 = -0.089841089295639 and x_2 = 0.7126562967865797
# Converged in 68 steps.  Loss fn = -1.0316284534857192 achieved by x_1 = -0.08984097945679492 and x_2 = 0.7126562841554867
# Converged in 67 steps.  Loss fn = -1.0316284534864237 achieved by x_1 = -0.08984107111249558 and x_2 = 0.7126562946955853
# Converged in 66 steps.  Loss fn = -1.0316284534869622 achieved by x_1 = -0.0898411476415573 and x_2 = 0.7126563034961673
# Converged in 64 steps.  Loss fn = -1.0316284534858953 achieved by x_1 = -0.08984100162450145 and x_2 = 0.7126562867047073
# Converged in 63 steps.  Loss fn = -1.0316284534863707 achieved by x_1 = -0.08984106382493119 and x_2 = 0.7126562938575478
# Converged in 62 steps.  Loss fn = -1.0316284534867366 achieved by x_1 = -0.08984111476386067 and x_2 = 0.712656299715352
# Converged in 61 steps.  Loss fn = -1.0316284534870173 achieved by x_1 = -0.08984115582357707 and x_2 = 0.7126563044370794
# Converged in 60 steps.  Loss fn = -1.0316284534872284 achieved by x_1 = -0.08984118808176778 and x_2 = 0.7126563081466607
# Converged in 59 steps.  Loss fn = -1.0316284534873816 achieved by x_1 = -0.08984121235793306 and x_2 = 0.7126563109383363
# Converged in 58 steps.  Loss fn = -1.031628453487486 achieved by x_1 = -0.08984122924761553 and x_2 = 0.712656312880592
# Converged in 57 steps.  Loss fn = -1.031628453487546 achieved by x_1 = -0.08984123914642225 and x_2 = 0.7126563140189213
# Converged in 56 steps.  Loss fn = -1.031628453487565 achieved by x_1 = -0.08984124226517773 and x_2 = 0.7126563143775686
# Converged in 55 steps.  Loss fn = -1.031628453487543 achieved by x_1 = -0.08984123863700244 and x_2 = 0.7126563139603427
# Converged in 54 steps.  Loss fn = -1.0316284534874793 achieved by x_1 = -0.08984122811661846 and x_2 = 0.7126563127505372
# Converged in 53 steps.  Loss fn = -1.0316284534873692 achieved by x_1 = -0.08984121037170667 and x_2 = 0.7126563107099365
# Converged in 52 steps.  Loss fn = -1.0316284534872076 achieved by x_1 = -0.08984118486563558 and x_2 = 0.7126563077768299
# Converged in 51 steps.  Loss fn = -1.0316284534869833 achieved by x_1 = -0.08984115083031308 and x_2 = 0.712656303862889
# Converged in 50 steps.  Loss fn = -1.0316284534866837 achieved by x_1 = -0.08984110722722528 and x_2 = 0.7126562988486885
# Converged in 50 steps.  Loss fn = -1.0316284534879383 achieved by x_1 = -0.08984130723782052 and x_2 = 0.7126563218491994
# Converged in 49 steps.  Loss fn = -1.03162845348768 achieved by x_1 = -0.08984126177925973 and x_2 = 0.7126563166216289
# Converged in 48 steps.  Loss fn = -1.0316284534873421 achieved by x_1 = -0.08984120597178005 and x_2 = 0.7126563102039688
# Converged in 47 steps.  Loss fn = -1.0316284534868962 achieved by x_1 = -0.08984113791090566 and x_2 = 0.7126563023772106
# Converged in 47 steps.  Loss fn = -1.0316284534880278 achieved by x_1 = -0.08984132377478728 and x_2 = 0.7126563237508949
# Converged in 46 steps.  Loss fn = -1.0316284534876434 achieved by x_1 = -0.08984125550550968 and x_2 = 0.7126563159001745
# Converged in 45 steps.  Loss fn = -1.0316284534871276 achieved by x_1 = -0.08984117253111482 and x_2 = 0.7126563063584164
# Converged in 45 steps.  Loss fn = -1.0316284534881475 achieved by x_1 = -0.0898413463782402 and x_2 = 0.7126563263502128
# Converged in 44 steps.  Loss fn = -1.0316284534876883 achieved by x_1 = -0.0898412630963396 and x_2 = 0.7126563167730959
# Converged in 43 steps.  Loss fn = -1.0316284534870528 achieved by x_1 = -0.08984116119554734 and x_2 = 0.7126563050548703
# Converged in 43 steps.  Loss fn = -1.0316284534880744 achieved by x_1 = -0.08984133246636887 and x_2 = 0.7126563247504005
# Converged in 42 steps.  Loss fn = -1.0316284534874847 achieved by x_1 = -0.08984122902505307 and x_2 = 0.7126563128550235
# Converged in 42 steps.  Loss fn = -1.0316284534883402 achieved by x_1 = -0.08984138470134619 and x_2 = 0.7126563307572342
# Converged in 41 steps.  Loss fn = -1.031628453487779 achieved by x_1 = -0.08984127878916232 and x_2 = 0.7126563185777188
# Converged in 40 steps.  Loss fn = -1.0316284534869538 achieved by x_1 = -0.08984114638150009 and x_2 = 0.7126563033513139
# Converged in 40 steps.  Loss fn = -1.0316284534879705 achieved by x_1 = -0.08984131313656057 and x_2 = 0.7126563225275468
# Converged in 39 steps.  Loss fn = -1.0316284534871418 achieved by x_1 = -0.08984117476429716 and x_2 = 0.7126563066152365
# Converged in 39 steps.  Loss fn = -1.0316284534880817 achieved by x_1 = -0.08984133379518425 and x_2 = 0.7126563249032148
# Converged in 38 steps.  Loss fn = -1.031628453487224 achieved by x_1 = -0.08984118736287447 and x_2 = 0.7126563080640299
# Converged in 38 steps.  Loss fn = -1.0316284534881226 achieved by x_1 = -0.08984134171375706 and x_2 = 0.7126563258138232
# Converged in 37 steps.  Loss fn = -1.0316284534872062 achieved by x_1 = -0.089841184630292 and x_2 = 0.7126563077497948
# Converged in 37 steps.  Loss fn = -1.0316284534880988 achieved by x_1 = -0.08984133713085557 and x_2 = 0.7126563252868077
# Converged in 37 steps.  Loss fn = -1.0316284534886961 achieved by x_1 = -0.08984146220075533 and x_2 = 0.7126563396693866
# Converged in 36 steps.  Loss fn = -1.0316284534880056 achieved by x_1 = -0.08984131957799506 and x_2 = 0.7126563232682942
# Converged in 36 steps.  Loss fn = -1.031628453488625 achieved by x_1 = -0.0898414458610932 and x_2 = 0.7126563377903867
# Converged in 35 steps.  Loss fn = -1.03162845348783 achieved by x_1 = -0.0898412878145596 and x_2 = 0.7126563196156164
# Converged in 35 steps.  Loss fn = -1.0316284534884979 achieved by x_1 = -0.08984141769293082 and x_2 = 0.7126563345511532
# Converged in 34 steps.  Loss fn = -1.0316284534875495 achieved by x_1 = -0.0898412396829043 and x_2 = 0.7126563140806527
# Converged in 34 steps.  Loss fn = -1.0316284534882967 achieved by x_1 = -0.0898413757788149 and x_2 = 0.7126563297311854
# Converged in 34 steps.  Loss fn = -1.0316284534888063 achieved by x_1 = -0.0898414885283469 and x_2 = 0.7126563426969645
# Converged in 33 steps.  Loss fn = -1.0316284534879925 achieved by x_1 = -0.08984131720131627 and x_2 = 0.7126563229949894
# Converged in 33 steps.  Loss fn = -1.031628453488591 achieved by x_1 = -0.08984143808536163 and x_2 = 0.7126563368962094
# Converged in 32 steps.  Loss fn = -1.0316284534875375 achieved by x_1 = -0.08984123769473727 and x_2 = 0.7126563138520245
# Converged in 32 steps.  Loss fn = -1.0316284534882667 achieved by x_1 = -0.0898413698318337 and x_2 = 0.712656329047307
# Converged in 32 steps.  Loss fn = -1.0316284534887714 achieved by x_1 = -0.08984148005741892 and x_2 = 0.7126563417228412
# Converged in 31 steps.  Loss fn = -1.0316284534877767 achieved by x_1 = -0.08984127841189965 and x_2 = 0.7126563185343516
# Converged in 31 steps.  Loss fn = -1.031628453488423 achieved by x_1 = -0.08984140179907645 and x_2 = 0.7126563327234233
# Converged in 31 steps.  Loss fn = -1.0316284534888724 achieved by x_1 = -0.08984150504144708 and x_2 = 0.7126563445959121
# Converged in 30 steps.  Loss fn = -1.0316284534878817 achieved by x_1 = -0.0898412970250739 and x_2 = 0.7126563206748003
# Converged in 30 steps.  Loss fn = -1.0316284534884872 achieved by x_1 = -0.08984141543998456 and x_2 = 0.7126563342920784
# Converged in 30 steps.  Loss fn = -1.0316284534889109 achieved by x_1 = -0.08984151483853964 and x_2 = 0.712656345722542
# Converged in 29 steps.  Loss fn = -1.0316284534878684 achieved by x_1 = -0.0898412945980837 and x_2 = 0.7126563203957071
# Converged in 29 steps.  Loss fn = -1.0316284534884688 achieved by x_1 = -0.08984141147454575 and x_2 = 0.7126563338360689
# Converged in 29 steps.  Loss fn = -1.0316284534888915 achieved by x_1 = -0.08984150990864426 and x_2 = 0.7126563451556233
# Converged in 29 steps.  Loss fn = -1.0316284534891893 achieved by x_1 = -0.08984159271920626 and x_2 = 0.7126563546785267
# Converged in 28 steps.  Loss fn = -1.0316284534883617 achieved by x_1 = -0.08984138903927634 and x_2 = 0.7126563312560974
# Converged in 28 steps.  Loss fn = -1.03162845348881 achieved by x_1 = -0.0898414893770205 and x_2 = 0.7126563427945642
# Converged in 28 steps.  Loss fn = -1.0316284534891271 achieved by x_1 = -0.08984157408309712 and x_2 = 0.712656352535445
# Converged in 27 steps.  Loss fn = -1.0316284534881426 achieved by x_1 = -0.08984134547452895 and x_2 = 0.7126563262463141
# Converged in 27 steps.  Loss fn = -1.0316284534886466 achieved by x_1 = -0.08984145083066628 and x_2 = 0.7126563383618786
# Converged in 27 steps.  Loss fn = -1.0316284534890063 achieved by x_1 = -0.08984154009713406 and x_2 = 0.712656348627188
# Converged in 27 steps.  Loss fn = -1.0316284534892628 achieved by x_1 = -0.08984161564769187 and x_2 = 0.712656357315217
# Converged in 26 steps.  Loss fn = -1.0316284534883655 achieved by x_1 = -0.08984138984334379 and x_2 = 0.7126563313485648
# Converged in 26 steps.  Loss fn = -1.0316284534887994 achieved by x_1 = -0.08984148683839077 and x_2 = 0.7126563425026333
# Converged in 26 steps.  Loss fn = -1.0316284534891105 achieved by x_1 = -0.08984156924349782 and x_2 = 0.7126563519789106
# Converged in 26 steps.  Loss fn = -1.0316284534893332 achieved by x_1 = -0.08984163917572979 and x_2 = 0.7126563600208526
# Converged in 25 steps.  Loss fn = -1.0316284534884514 achieved by x_1 = -0.08984140785202939 and x_2 = 0.712656333419498
# Converged in 25 steps.  Loss fn = -1.0316284534888551 achieved by x_1 = -0.08984150061934355 and x_2 = 0.7126563440873921
# Converged in 25 steps.  Loss fn = -1.0316284534891458 achieved by x_1 = -0.08984157966136705 and x_2 = 0.712656353176927
# Converged in 25 steps.  Loss fn = -1.0316284534893556 achieved by x_1 = -0.0898416469340643 and x_2 = 0.7126563609130322
# Converged in 24 steps.  Loss fn = -1.0316284534884175 achieved by x_1 = -0.08984140065626746 and x_2 = 0.7126563325920136
# Converged in 24 steps.  Loss fn = -1.0316284534888247 achieved by x_1 = -0.08984149296199781 and x_2 = 0.712656343206827
# Converged in 24 steps.  Loss fn = -1.0316284534891196 achieved by x_1 = -0.08984157185574698 and x_2 = 0.7126563522793109
# Converged in 24 steps.  Loss fn = -1.0316284534893334 achieved by x_1 = -0.08984163921151582 and x_2 = 0.7126563600249689
# Converged in 24 steps.  Loss fn = -1.0316284534894877 achieved by x_1 = -0.0898416966521629 and x_2 = 0.7126563666304245
# Converged in 23 steps.  Loss fn = -1.0316284534886948 achieved by x_1 = -0.08984146184389107 and x_2 = 0.7126563396283626
# Converged in 23 steps.  Loss fn = -1.031628453489021 achieved by x_1 = -0.08984154391712232 and x_2 = 0.7126563490664753
# Converged in 23 steps.  Loss fn = -1.0316284534892577 achieved by x_1 = -0.08984161422292677 and x_2 = 0.7126563571513767
# Converged in 23 steps.  Loss fn = -1.0316284534894307 achieved by x_1 = -0.08984167438127459 and x_2 = 0.7126563640693578
# Converged in 22 steps.  Loss fn = -1.0316284534884226 achieved by x_1 = -0.08984140172205597 and x_2 = 0.712656332714578
# Converged in 22 steps.  Loss fn = -1.0316284534888158 achieved by x_1 = -0.0898414908646612 and x_2 = 0.7126563429656432
# Converged in 22 steps.  Loss fn = -1.0316284534891045 achieved by x_1 = -0.08984156750418963 and x_2 = 0.7126563517788996
# Converged in 22 steps.  Loss fn = -1.0316284534893159 achieved by x_1 = -0.08984163332161103 and x_2 = 0.7126563593476533
# Converged in 22 steps.  Loss fn = -1.0316284534894704 achieved by x_1 = -0.08984168978203548 and x_2 = 0.7126563658403866
# Converged in 22 steps.  Loss fn = -1.0316284534895832 achieved by x_1 = -0.08984173816109176 and x_2 = 0.7126563714037928
# Converged in 21 steps.  Loss fn = -1.0316284534888147 achieved by x_1 = -0.08984149051437038 and x_2 = 0.7126563429253662
# Converged in 21 steps.  Loss fn = -1.0316284534890987 achieved by x_1 = -0.08984156588478671 and x_2 = 0.7126563515926811
# Converged in 21 steps.  Loss fn = -1.0316284534893085 achieved by x_1 = -0.08984163079873089 and x_2 = 0.7126563590575388
# Converged in 21 steps.  Loss fn = -1.0316284534894624 achieved by x_1 = -0.0898416866451691 and x_2 = 0.7126563654796623
# Converged in 21 steps.  Loss fn = -1.0316284534895757 achieved by x_1 = -0.08984173463718685 and x_2 = 0.7126563709985437
# Converged in 20 steps.  Loss fn = -1.0316284534886797 achieved by x_1 = -0.08984145831274756 and x_2 = 0.7126563392225654
# Converged in 20 steps.  Loss fn = -1.031628453488994 achieved by x_1 = -0.08984153662499819 and x_2 = 0.7126563482286428
# Converged in 20 steps.  Loss fn = -1.0316284534892273 achieved by x_1 = -0.08984160429596172 and x_2 = 0.712656356011513
# Converged in 20 steps.  Loss fn = -1.0316284534893994 achieved by x_1 = -0.08984166270867938 and x_2 = 0.7126563627306425
# Converged in 20 steps.  Loss fn = -1.031628453489527 achieved by x_1 = -0.08984171307515876 and x_2 = 0.7126563685261179
# Converged in 20 steps.  Loss fn = -1.031628453489621 achieved by x_1 = -0.08984175645636079 and x_2 = 0.71265637352111
# Converged in 20 steps.  Loss fn = -1.0316284534896905 achieved by x_1 = -0.0898417937799762 and x_2 = 0.712656377824158
# Converged in 19 steps.  Loss fn = -1.031628453489028 achieved by x_1 = -0.08984154593529209 and x_2 = 0.7126563491486866
# Converged in 19 steps.  Loss fn = -1.0316284534892475 achieved by x_1 = -0.0898416108035774 and x_2 = 0.7126563565090256
# Converged in 19 steps.  Loss fn = -1.031628453489411 achieved by x_1 = -0.08984166696634988 and x_2 = 0.7126563628124789
# Converged in 19 steps.  Loss fn = -1.0316284534895328 achieved by x_1 = -0.08984171554725999 and x_2 = 0.7126563681619097
# Converged in 19 steps.  Loss fn = -1.0316284534896225 achieved by x_1 = -0.08984175753416836 and x_2 = 0.7126563726345391
# Converged in 19 steps.  Loss fn = -1.0316284534896896 achieved by x_1 = -0.08984179379523546 and x_2 = 0.7126563762811704
# Converged in 19 steps.  Loss fn = -1.0316284534897393 achieved by x_1 = -0.08984182509330715 and x_2 = 0.7126563791251794
# Converged in 18 steps.  Loss fn = -1.0316284534891516 achieved by x_1 = -0.08984158037753415 and x_2 = 0.7126563629758437
# Converged in 18 steps.  Loss fn = -1.0316284534893325 achieved by x_1 = -0.08984163795931308 and x_2 = 0.712656373577601
# Converged in 18 steps.  Loss fn = -1.031628453489468 achieved by x_1 = -0.08984168774773807 and x_2 = 0.7126563845718951
# Converged in 18 steps.  Loss fn = -1.031628453489568 achieved by x_1 = -0.08984173068417461 and x_2 = 0.7126563963207182
# Converged in 18 steps.  Loss fn = -1.0316284534896405 achieved by x_1 = -0.08984176759790632 and x_2 = 0.7126564091315206
# Converged in 18 steps.  Loss fn = -1.0316284534896918 achieved by x_1 = -0.08984179922791778 and x_2 = 0.7126564231840188
# Converged in 18 steps.  Loss fn = -1.0316284534897244 achieved by x_1 = -0.0898418262487298 and x_2 = 0.7126564384093251
# Converged in 18 steps.  Loss fn = -1.0316284534897429 achieved by x_1 = -0.0898418493029079 and x_2 = 0.7126564542997953
# Converged in 17 steps.  Loss fn = -1.0316284534889435 achieved by x_1 = -0.08984164383280237 and x_2 = 0.7126561577959252
# Converged in 17 steps.  Loss fn = -1.0316284534890134 achieved by x_1 = -0.0898416957706188 and x_2 = 0.7126561429287738
# Converged in 17 steps.  Loss fn = -1.0316284534891074 achieved by x_1 = -0.08984173943469603 and x_2 = 0.7126561441073854
# Converged in 17 steps.  Loss fn = -1.0316284534892868 achieved by x_1 = -0.08984177392381193 and x_2 = 0.7126561761182812
# Converged in 17 steps.  Loss fn = -1.0316284534895614 achieved by x_1 = -0.08984179738275747 and x_2 = 0.7126562611823439
# Converged in 17 steps.  Loss fn = -1.0316284534896987 achieved by x_1 = -0.08984180669134675 and x_2 = 0.7126564317426554
# Converged in 18 steps.  Loss fn = -1.0316284534896474 achieved by x_1 = -0.08984197543191326 and x_2 = 0.712656235149831
# Converged in 19 steps.  Loss fn = -1.0316284534895894 achieved by x_1 = -0.08984197636489509 and x_2 = 0.7126565866153343
# Converged in 20 steps.  Loss fn = -1.0316284534896203 achieved by x_1 = -0.08984202914391855 and x_2 = 0.7126562270822134
# Converged in 21 steps.  Loss fn = -1.031628453489679 achieved by x_1 = -0.08984199427382539 and x_2 = 0.7126565571812594
# Converged in 21 steps.  Loss fn = -1.0316284534892832 achieved by x_1 = -0.08984198153034638 and x_2 = 0.7126566694988381
# Converged in 22 steps.  Loss fn = -1.0316284534894722 achieved by x_1 = -0.0898420381771743 and x_2 = 0.7126561828970343
# Converged in 23 steps.  Loss fn = -1.0316284534896039 achieved by x_1 = -0.08984199223285813 and x_2 = 0.7126565839650236
# Converged in 23 steps.  Loss fn = -1.0316284534891855 achieved by x_1 = -0.08984197996049154 and x_2 = 0.7126566907611143
# Converged in 24 steps.  Loss fn = -1.0316284534894207 achieved by x_1 = -0.08984203996607353 and x_2 = 0.7126561692844309
# Converged in 25 steps.  Loss fn = -1.0316284534895734 achieved by x_1 = -0.08984199117676406 and x_2 = 0.7126565936367605
# Converged in 25 steps.  Loss fn = -1.0316284534891857 achieved by x_1 = -0.08984198001126475 and x_2 = 0.7126566907315707
# Converged in 26 steps.  Loss fn = -1.0316284534894267 achieved by x_1 = -0.08984203980639714 and x_2 = 0.7126561707763931
# Converged in 26 steps.  Loss fn = -1.0316284534889388 achieved by x_1 = -0.08984205163651493 and x_2 = 0.7126560678999827
# Converged in 27 steps.  Loss fn = -1.031628453489293 achieved by x_1 = -0.0898419826865179 and x_2 = 0.7126566674925553
# Converged in 28 steps.  Loss fn = -1.031628453489524 achieved by x_1 = -0.08984203675906488 and x_2 = 0.7126561972832502
# Converged in 28 steps.  Loss fn = -1.031628453489283 achieved by x_1 = -0.08984204377203389 and x_2 = 0.7126561362980112
# Converged in 28 steps.  Loss fn = -1.0316284534890308 achieved by x_1 = -0.08984204971036928 and x_2 = 0.7126560846579202
# Converged in 28 steps.  Loss fn = -1.0316284534889688 achieved by x_1 = -0.08984205101723006 and x_2 = 0.7126560732937687
# Converged in 28 steps.  Loss fn = -1.0316284534893823 achieved by x_1 = -0.08984204109679114 and x_2 = 0.7126561595631591
# Converged in 24 steps.  Loss fn = -1.031628453489405 achieved by x_1 = -0.08984198575593093 and x_2 = 0.7126566407910571
# Converged in 30 steps.  Loss fn = -1.0316284534893654 achieved by x_1 = -0.08984198464384027 and x_2 = 0.7126566504753857
# Converged in 32 steps.  Loss fn = -1.0316284534892608 achieved by x_1 = -0.08984198186446642 and x_2 = 0.7126566746445326
# Converged in 33 steps.  Loss fn = -1.0316284534888338 achieved by x_1 = -0.0898420537449586 and x_2 = 0.7126560495746637
# Converged in 34 steps.  Loss fn = -1.031628453488639 achieved by x_1 = -0.08984196883041201 and x_2 = 0.7126567879868784
# Converged in 35 steps.  Loss fn = -1.0316284534888656 achieved by x_1 = -0.08984205311549526 and x_2 = 0.7126560550488298
# Converged in 35 steps.  Loss fn = -1.031628453488975 achieved by x_1 = -0.08984205088812565 and x_2 = 0.7126560744182512
# Converged in 30 steps.  Loss fn = -1.03162845348874 achieved by x_1 = -0.0898420555308167 and x_2 = 0.7126560340453365
# Converged in 38 steps.  Loss fn = -1.03162845348897 achieved by x_1 = -0.08984205100078738 and x_2 = 0.7126560734387298
# Converged in 40 steps.  Loss fn = -1.031628453488928 achieved by x_1 = -0.08984205186287349 and x_2 = 0.712656065942088
# Converged in 38 steps.  Loss fn = -1.0316284534890878 achieved by x_1 = -0.08984204844282169 and x_2 = 0.7126560956829943
# Converged in 43 steps.  Loss fn = -1.0316284534889089 achieved by x_1 = -0.08984205225213228 and x_2 = 0.7126560625572292
# Converged in 43 steps.  Loss fn = -1.0316284534890288 achieved by x_1 = -0.08984197645461763 and x_2 = 0.7126567216886808
# Converged in 47 steps.  Loss fn = -1.0316284534885016 achieved by x_1 = -0.08984205976750188 and x_2 = 0.7126559972035582
# Converged in 49 steps.  Loss fn = -1.0316284534883913 achieved by x_1 = 0.08984196460690162 and x_2 = -0.7126568247151015
# Converged in 49 steps.  Loss fn = -1.0316284534887963 achieved by x_1 = 0.08984197173254013 and x_2 = -0.7126567627514799
# Converged in 49 steps.  Loss fn = -1.0316284534882494 achieved by x_1 = 0.08984206385878743 and x_2 = -0.7126559616258699
# Converged in 48 steps.  Loss fn = -1.0316284534887377 achieved by x_1 = 0.08984205557184106 and x_2 = -0.7126560336893327
# Converged in 51 steps.  Loss fn = -1.0316284534881641 achieved by x_1 = 0.089841961022113 and x_2 = -0.7126568558882577
# Converged in 45 steps.  Loss fn = -1.0316284534887799 achieved by x_1 = 0.08984197143193803 and x_2 = -0.7126567653656626
# Converged in 53 steps.  Loss fn = -1.0316284534880344 achieved by x_1 = 0.08984206710712184 and x_2 = -0.7126559333785594
# Converged in 56 steps.  Loss fn = -1.0316284534880749 achieved by x_1 = 0.08984195968920078 and x_2 = -0.7126568674792843
# Converged in 57 steps.  Loss fn = -1.0316284534883273 achieved by x_1 = 0.08984206263321144 and x_2 = -0.7126559722838388
# Converged in 52 steps.  Loss fn = -1.0316284534885676 achieved by x_1 = 0.08984196757436465 and x_2 = -0.7126567989108638
# Converged in 59 steps.  Loss fn = -1.031628453488086 achieved by x_1 = 0.08984195985453833 and x_2 = -0.712656866041681
# Converged in 65 steps.  Loss fn = -1.031628453488308 achieved by x_1 = 0.08984196326690017 and x_2 = -0.7126568363681959
# Converged in 69 steps.  Loss fn = -1.0316284534883617 achieved by x_1 = 0.08984196412606564 and x_2 = -0.7126568288970198
# Converged in 72 steps.  Loss fn = -1.0316284534882352 achieved by x_1 = 0.08984206407957089 and x_2 = -0.7126559597064944
# Converged in 74 steps.  Loss fn = -1.0316284534879436 achieved by x_1 = 0.08984206841781718 and x_2 = -0.7126559219811373
# Converged in 75 steps.  Loss fn = -1.031628453488078 achieved by x_1 = 0.08984195973250741 and x_2 = -0.7126568671030513
# Converged in 66 steps.  Loss fn = -1.0316284534879956 achieved by x_1 = 0.08984206767156429 and x_2 = -0.7126559284706284
# Converged in 81 steps.  Loss fn = -1.0316284534876439 achieved by x_1 = 0.08984207255248057 and x_2 = -0.7126558860262133
# Converged in 92 steps.  Loss fn = -1.0316284534878148 achieved by x_1 = 0.08984195596941247 and x_2 = -0.71265689982664
# Converged in 101 steps.  Loss fn = -1.0316284534877949 achieved by x_1 = 0.08984207050616871 and x_2 = -0.7126559038210151
# Converged in 110 steps.  Loss fn = -1.0316284534877502 achieved by x_1 = 0.08984195508206091 and x_2 = -0.7126569075430256
# Converged in 120 steps.  Loss fn = -1.0316284534878064 achieved by x_1 = 0.08984195585116138 and x_2 = -0.7126569008550375
# Converged in 130 steps.  Loss fn = -1.0316284534873161 achieved by x_1 = 0.0898419494314484 and x_2 = -0.7126569566802372
# Converged in 143 steps.  Loss fn = -1.0316284534873925 achieved by x_1 = 0.08984207581092354 and x_2 = -0.7126558576910118
# Converged in 158 steps.  Loss fn = -1.0316284534873668 achieved by x_1 = 0.08984195006528914 and x_2 = -0.7126569511684923
# Converged in 176 steps.  Loss fn = -1.0316284534874591 achieved by x_1 = 0.08984195123228111 and x_2 = -0.7126569410204792
# Converged in 195 steps.  Loss fn = -1.0316284534871338 achieved by x_1 = 0.0898420789941794 and x_2 = -0.7126558300095254
# Converged in 212 steps.  Loss fn = -1.0316284534871432 achieved by x_1 = 0.08984194732033754 and x_2 = -0.7126569750384091
# Converged in 240 steps.  Loss fn = -1.0316284534871216 achieved by x_1 = 0.0898420791402995 and x_2 = -0.7126558287389289
# Converged in 352 steps.  Loss fn = -1.0316284534871107 achieved by x_1 = 0.08984207926997731 and x_2 = -0.7126558276112812
# Converged in 507 steps.  Loss fn = -1.0316284534869575 achieved by x_1 = 0.0898419451227647 and x_2 = -0.7126569941483739
# Converged in 840 steps.  Loss fn = -1.0316284534868976 achieved by x_1 = 0.08984208177152807 and x_2 = -0.7126558058578675
# Converged in 2353 steps.  Loss fn = -1.031628453486851 achieved by x_1 = 0.08984194389253092 and x_2 = -0.7126570048464234
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# Did not converge
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-107-2681c6595661> in <module>()
#       4 for j in range (1,1000):
#       5   r=(j/2000)
# ----> 6   solver.find_min(x_1_init=1, x_2_init=1, n_iter = 10000, eta=r, tol=1e-5)
#       7   eta_path.append(r)
#       8   stepsize_path.append(solver.num_step)
#
# <ipython-input-102-532c1247efe7> in find_min(self, x_1_init, x_2_init, n_iter, eta, tol)
#      38             x_1_path.append(x_1)
#      39             x_2_path.append(x_2)
# ---> 40             loss_this = self.fn_loss(x_1,x_2)
#      41             loss_path.append(loss_this)
#      42
#
# <ipython-input-94-bd779e84c603> in fn_loss(x_1, x_2)
#       1 def fn_loss(x_1,x_2):
# ----> 2     return (4*x_1**2) - 2.1*x_1**4 + (x_1**6)/3 + x_1*x_2 - 4*x_2**2 + 4*x_2**4
#       3
#       4 def fn_grad1(x_1,x_2):
#       5     return 8*x_1 - 8.4*x_1**3 + 2*x_1**5 + x_2
#
# OverflowError: (34, 'Numerical result out of range')

# %%
font = {'size': 18}
matplotlib.rc('font', **font)


fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(eta_path, stepsize_path)
ax1.set_xlabel('eta')
ax1.set_ylabel('number_of_steps')
# Out:
# Text(0, 0.5, 'number_of_steps')
